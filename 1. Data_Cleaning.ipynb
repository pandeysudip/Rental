# %% [markdown]
# # Data Importing and Data Preparation

# %%
# Dependencies and setup
import numpy as np
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
import seaborn as sns
import csv
from datetime import date
from uszipcode import SearchEngine

# %%
# defining data path
path=Path('Resources/Raw_data/testData.csv')

# %%
# Reading data source using pandas
rent_df=pd.read_csv(path)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# /var/folders/ld/_spx9cwj74z4zm921xp1zssh0000gn/T/ipykernel_70668/732404320.py in <module>
#       1 # Reading data source using pandas
# ----> 2 rent_df=pd.read_csv(path)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     486
#     487     with parser:
# --> 488         return parser.read(nrows)
#     489
#     490
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers/readers.py in read(self, nrows)
#    1045     def read(self, nrows=None):
#    1046         nrows = validate_integer("nrows", nrows)
# -> 1047         index, columns, col_dict = self._engine.read(nrows)
#    1048
#    1049         if index is None:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers/c_parser_wrapper.py in read(self, nrows)
#     221         try:
#     222             if self.low_memory:
# --> 223                 chunks = self._reader.read_low_memory(nrows)
#     224                 # destructive to chunks
#     225                 data = _concatenate_chunks(chunks)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read_low_memory()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 7 fields in line 172, saw 8

# %% [markdown]
# ### Getting an error with 7 columns name but some rows have 8 columns.
# ### Using CSV reader to get the columns name and handaling this error so that can easily read with pandas

# %%
# Reading a csv file using CSV module for handaling error
with open(path, 'r') as f:
    csv_reader = csv.reader(f, delimiter=',')
    columns = next(csv_reader)
    print(columns)
# Out:
# ['name', 'dob', 'houseID', 'houseZip', 'paymentDate', 'paymentAmount', 'rentAmount']

# %%
# Defining the columns name(adding new column name "extra")
names=columns+["extra"]

# %%
# Reading data source using pandas read_csv
rent_df=pd.read_csv(path, skiprows=1,names=names)

# %% [markdown]
# ## Data Understanding

# %%
#Looking top rows of rent_df dataframe
rent_df.head()
# Out:
#                 name         dob houseID  houseZip paymentDate paymentAmount  \
# 0     Karima Germany  05/23/1951    1192     92154  11/01/2011          1321
# 1    Agustina Spargo  01/01/1900      21     92111    20110906          2289
# 2  Lucilla Broderick  01/01/1900    1474     92159    20111101          1439
# 3        Russ Mchale  04/20/1977    2015     92137    20120701          1744
# 4   Carmelita Ritzer  03/09/1969     311     92136    20110201          1471
#
#    rentAmount  extra
# 0      1321.0    NaN
# 1      2289.0    NaN
# 2      1439.0    NaN
# 3      1744.0    NaN
# 4      1471.0    NaN

# %%
# Columns of rent_df dataframe
rent_df.columns
# Out:
# Index(['name', 'dob', 'houseID', 'houseZip', 'paymentDate', 'paymentAmount',
#        'rentAmount', 'extra'],
#       dtype='object')

# %%
# Shape of rent_df datafrmae
shape=rent_df.shape
print(f'The number of rows are: {shape[0]}, number of columns are: {shape[1]}')
# Out:
# The number of rows are: 59813, number of columns are: 8

# %%
#Information of the dataframe using .info()
rent_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59813 entries, 0 to 59812
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           56903 non-null  object
#  1   dob            59813 non-null  object
#  2   houseID        59813 non-null  object
#  3   houseZip       59813 non-null  int64
#  4   paymentDate    59813 non-null  object
#  5   paymentAmount  59281 non-null  object
#  6   rentAmount     59775 non-null  float64
#  7   extra          2910 non-null   float64
# dtypes: float64(2), int64(1), object(5)
# memory usage: 3.7+ MB

# %%
#looking for nan value
rent_df.isna().sum()
# Out:
# name              2910
# dob                  0
# houseID              0
# houseZip             0
# paymentDate          0
# paymentAmount      532
# rentAmount          38
# extra            56903
# dtype: int64

# %%
#filling NAN with 0 in extra column
rent_df['extra']=rent_df['extra'].fillna(0)
rent_df
# Out:
#                     name         dob houseID  houseZip paymentDate  \
# 0         Karima Germany  05/23/1951    1192     92154  11/01/2011
# 1        Agustina Spargo  01/01/1900      21     92111    20110906
# 2      Lucilla Broderick  01/01/1900    1474     92159    20111101
# 3            Russ Mchale  04/20/1977    2015     92137    20120701
# 4       Carmelita Ritzer  03/09/1969     311     92136    20110201
# ...                  ...         ...     ...       ...         ...
# 59808  Jennell Buchholtz  05/21/1983    1095     92196    20101001
# 59809     Berneice Power  08/24/1984     196     92123    20100401
# 59810       Micki Belvin  01/01/1900    1692     92166    20120701
# 59811     Emilee Samford  01/01/1900     686     92191    20120528
# 59812    Astrid Laurence  05/15/1988     159     92120  01/01/2011
#
#       paymentAmount  rentAmount  extra
# 0              1321      1321.0    0.0
# 1              2289      2289.0    0.0
# 2              1439      1439.0    0.0
# 3              1744      1744.0    0.0
# 4              1471      1471.0    0.0
# ...             ...         ...    ...
# 59808          1744      1744.0    0.0
# 59809          1756      1756.0    0.0
# 59810          1896      1896.0    0.0
# 59811          1668      1451.0    0.0
# 59812          1134      1134.0    0.0
#
# [59813 rows x 8 columns]

# %% [markdown]
# ## Correcting Columns Shift

# %% [markdown]
# ## Since some rows are shifted one column up, correcting this error using shift method.

# %%
#Get all rows by mask
mask = rent_df['extra'] != 0.0
#All columns name
c = list(rent_df.columns)
#Shift columns, by converting to strings
rent_df.loc[mask, c] = rent_df.loc[mask, c].astype(str).shift(-1, axis=1)

# %%
#Dropping the extra column after shifting rows correctly
rent_df.drop(columns="extra", axis=1, inplace=True)

# %%
#Looking top rows of  corrected rent_df dataframe
rent_df.head()
# Out:
#                 name         dob houseID houseZip paymentDate paymentAmount  \
# 0     Karima Germany  05/23/1951    1192    92154  11/01/2011          1321
# 1    Agustina Spargo  01/01/1900      21    92111    20110906          2289
# 2  Lucilla Broderick  01/01/1900    1474    92159    20111101          1439
# 3        Russ Mchale  04/20/1977    2015    92137    20120701          1744
# 4   Carmelita Ritzer  03/09/1969     311    92136    20110201          1471
#
#   rentAmount
# 0     1321.0
# 1     2289.0
# 2     1439.0
# 3     1744.0
# 4     1471.0

# %% [markdown]
# ## Converting Columns to Appropriate Datatypes

# %%
#Converting column to appropriate datatypes
rent_df['dob']=pd.to_datetime(rent_df['dob']).dt.date
rent_df['paymentDate']=pd.to_datetime(rent_df['paymentDate']).dt.date
rent_df['houseID']=rent_df['houseID'].astype('int')
rent_df['paymentAmount']=rent_df['paymentAmount'].astype('float')
rent_df['rentAmount']=rent_df['rentAmount'].astype('float')

# %% [markdown]
# ## Adding Age Columns Using Date of Birth Column

# %%
#Adding the age columns using date of birth
rent_df["age"] = rent_df["dob"].apply(lambda x : (date.today().year - x.year))

# %%
# Shape of rent_df datafrmae
shape=rent_df.shape
print(f'The number of rows are: {shape[0]}, number of columns are: {shape[1]}')
# Out:
# The number of rows are: 59813, number of columns are: 8

# %%
# looking for statistical terms(transpose for better visulization)
rent_df.describe().T
# Out:
#                  count         mean         std    min     25%     50%  \
# houseID        59813.0  1236.777105  715.827165    1.0   610.0  1240.0
# paymentAmount  59243.0  1511.771461  360.332519 -348.0  1318.0  1522.0
# rentAmount     59813.0  1505.651330  303.685935  428.0  1310.0  1506.0
# age            59813.0    82.674268   40.686114   -8.0    43.0    85.0
#
#                   75%     max
# houseID        1860.0  2475.0
# paymentAmount  1739.0  2861.0
# rentAmount     1720.0  2647.0
# age             122.0   122.0

# %% [markdown]
# # Taking Care of Missing Data

# %%
#looking for nan value
rent_df.isna().sum()
# Out:
# name               0
# dob                0
# houseID            0
# houseZip           0
# paymentDate        0
# paymentAmount    570
# rentAmount         0
# age                0
# dtype: int64

# %%
#Info of the corrected dataframe
rent_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59813 entries, 0 to 59812
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           59813 non-null  object
#  1   dob            59813 non-null  object
#  2   houseID        59813 non-null  int64
#  3   houseZip       59813 non-null  object
#  4   paymentDate    59813 non-null  object
#  5   paymentAmount  59243 non-null  float64
#  6   rentAmount     59813 non-null  float64
#  7   age            59813 non-null  int64
# dtypes: float64(2), int64(2), object(4)
# memory usage: 3.7+ MB

# %%
#filling NAN with 0 in paymentAmount column
rent_df['paymentAmount']=rent_df['paymentAmount'].fillna(0)

# %% [markdown]
# ### Missing date of birth is with 1900-01-01. Need to remove missing date of birth for visulization or model building.

# %%
# Looking for rows with date of birth 1900-01-01
rent_df.loc[rent_df["dob"].apply(lambda x : x.year)==1900, ['dob', 'age']]
# Out:
#               dob  age
# 1      1900-01-01  122
# 2      1900-01-01  122
# 6      1900-01-01  122
# 7      1900-01-01  122
# 12     1900-01-01  122
# ...           ...  ...
# 59800  1900-01-01  122
# 59802  1900-01-01  122
# 59806  1900-01-01  122
# 59810  1900-01-01  122
# 59811  1900-01-01  122
#
# [29869 rows x 2 columns]

# %%
# Age above 1 and below 110
rent_df.loc[(rent_df['age']<1) | (rent_df['age']>110), ['name', 'dob','age']]
# Out:
#                     name         dob  age
# 1        Agustina Spargo  1900-01-01  122
# 2      Lucilla Broderick  1900-01-01  122
# 6           Theda Howard  1900-01-01  122
# 7           Delmar Facey  1900-01-01  122
# 12          Santo Hanney  1900-01-01  122
# ...                  ...         ...  ...
# 59800   Leola Derrickson  1900-01-01  122
# 59802     Cherise Chaney  1900-01-01  122
# 59806   Millard Woodford  1900-01-01  122
# 59810       Micki Belvin  1900-01-01  122
# 59811     Emilee Samford  1900-01-01  122
#
# [29933 rows x 3 columns]

# %% [markdown]
# #### 29933 rows are missing date of birth
# #### Will remove the missing date from date of birth column later while visulization and model building.

# %% [markdown]
# ## Saving the Cleaned Data for Visualization and Model Building

# %%
# Cleaned dataframe
rent_df.head(20)
# Out:
#                  name         dob  houseID houseZip paymentDate  \
# 0      Karima Germany  1951-05-23     1192    92154  2011-11-01
# 1     Agustina Spargo  1900-01-01       21    92111  2011-09-06
# 2   Lucilla Broderick  1900-01-01     1474    92159  2011-11-01
# 3         Russ Mchale  1977-04-20     2015    92137  2012-07-01
# 4    Carmelita Ritzer  1969-03-09      311    92136  2011-02-01
# 5     Clifton Ellwood  1993-11-02      430    92103  2011-11-01
# 6        Theda Howard  1900-01-01     2260    92161  2011-09-01
# 7        Delmar Facey  1900-01-01      541    92161  2011-12-01
# 8     Lashawn Rotella  1985-12-05     1336    92190  2011-07-01
# 9    Tianna Greenwell  1983-01-14     2273    92190  2010-05-01
# 10         Jillian Xu  1981-11-19     1115    92177  2010-05-08
# 11        Taneka Noto  1992-05-09     2216    92110  2011-03-01
# 12       Santo Hanney  1900-01-01     2052    92174  2012-07-01
# 13         Betsey Son  1980-08-15      205    92162  2012-08-01
# 14        Curtis Sher  1996-10-14      463    92130  2010-09-01
# 15       Britni Friel  1981-03-17      247    92195  2010-02-01
# 16   Claretta Carasco  1964-11-25      409    92170  2011-04-11
# 17         Kasi Kilgo  1900-01-01     1209    92132  2011-06-01
# 18    Harland Liggins  1983-11-28      910    92194  2011-02-01
# 19      Sonny Hayslip  1982-08-26     2160    92168  2012-04-08
#
#     paymentAmount  rentAmount  age
# 0          1321.0      1321.0   71
# 1          2289.0      2289.0  122
# 2          1439.0      1439.0  122
# 3          1744.0      1744.0   45
# 4          1471.0      1471.0   53
# 5          1233.0      1233.0   29
# 6          1850.0      1850.0  122
# 7          1587.0      1587.0  122
# 8          1930.0      1930.0   37
# 9          1597.0      1597.0   39
# 10         1320.0      1320.0   41
# 11          988.0       988.0   30
# 12         1750.0      1750.0  122
# 13         1560.0      1560.0   42
# 14         1169.0      1169.0   26
# 15         1370.0      1370.0   41
# 16         1698.0      1544.0   58
# 17         1539.0      1539.0  122
# 18         1978.0      1978.0   39
# 19         1531.0      1531.0   40

# %%
#saving the cleaned data 
rent_df.to_csv('Resources/Cleaned_data/cleaned_rent_data.csv', index=False)

# %%
# Saving as html for website table
rent_df.to_html("Resources/Cleaned_data/rent_data.html")

# %% [markdown]
# # Feature Selection and Feature Engineering
# ### In this section, I added more columns using the house zipcode provided. Used SearchEngine module to add following columns:
# 1. Lattitude
# 2. Longitude
# 3. City
# 4. State
# 5. County
# 6. Median Income
# 7. Population
# 8. Housing Units
# 9. Occupied Housing Units

# %%
# Making copy of the rent_df dataframe
model_df=rent_df.copy()

# %%
model_df.head()
# Out:
#                 name         dob  houseID houseZip paymentDate  paymentAmount  \
# 0     Karima Germany  1951-05-23     1192    92154  2011-11-01         1321.0
# 1    Agustina Spargo  1900-01-01       21    92111  2011-09-06         2289.0
# 2  Lucilla Broderick  1900-01-01     1474    92159  2011-11-01         1439.0
# 3        Russ Mchale  1977-04-20     2015    92137  2012-07-01         1744.0
# 4   Carmelita Ritzer  1969-03-09      311    92136  2011-02-01         1471.0
#
#    rentAmount  age
# 0      1321.0   71
# 1      2289.0  122
# 2      1439.0  122
# 3      1744.0   45
# 4      1471.0   53

# %%
# Using SearchEngine module to get the information using the zipcode
search = SearchEngine()
result = search.by_zipcode('92159')
result
# Out:
# SimpleZipcode(zipcode='92159', zipcode_type='PO Box', major_city='San Diego', post_office_city=None, common_city_list=['San Diego'], county='San Diego County', state='CA', lat=None, lng=None, timezone=None, radius_in_miles=None, area_code_list=['619'], population=None, population_density=None, land_area_in_sqmi=None, water_area_in_sqmi=None, housing_units=None, occupied_housing_units=None, median_home_value=None, median_household_income=None, bounds_west=None, bounds_east=None, bounds_north=None, bounds_south=None)

# %% [markdown]
# ## Adding New Columns to the Data

# %%
#Adding city, county, lat, lng, housing units columns  to dataframe using SearchEngine module
model_df["city"]=''
model_df["county"]=''
model_df['lat']=''
model_df['lng']=''
model_df['housingUnits']=''
model_df['occupiedHousingUnits']=''
model_df['medianIncome']=''
model_df['population']=''
model_df['state']=''
for index, row in rent_df.iterrows():

    # Get zipcode from dataframe
    zipcode = str(row['houseZip'])
    #Searching by zipcode
    search = SearchEngine()
    result = search.by_zipcode(zipcode)
    #Adding columns
    try:
        model_df.loc[index, 'city'] = result.city
        model_df.loc[index, 'county'] = result.county
        model_df.loc[index, 'lat'] = result.lat
        model_df.loc[index, 'lng'] = result.lng
        model_df.loc[index, 'housingUnits'] = result.housing_units
        model_df.loc[index, 'occupiedHousingUnits'] = result.occupied_housing_units
        model_df.loc[index, 'medianIncome'] = result.median_household_income
        model_df.loc[index, 'population'] = result.population
        model_df.loc[index, 'state'] = result.state
    except (KeyError, IndexError):
        print("Missing field/result for... skipping.")

# %%
#Saving data for later use in modeling and visulization
model_df.to_csv('Resources/Cleaned_data/clean_added_data.csv', index=False)

# %% [markdown]
# ## Cleaning Data for Machine Learning

# %%
# Reading the recently saved data with new columns 
new_df=pd.read_csv('Resources/Cleaned_data/clean_added_data.csv')

# %%
#Recently saved data with new columns 
new_df.head()
# Out:
#                 name         dob  houseID  houseZip paymentDate  \
# 0     Karima Germany  1951-05-23     1192     92154  2011-11-01
# 1    Agustina Spargo  1900-01-01       21     92111  2011-09-06
# 2  Lucilla Broderick  1900-01-01     1474     92159  2011-11-01
# 3        Russ Mchale  1977-04-20     2015     92137  2012-07-01
# 4   Carmelita Ritzer  1969-03-09      311     92136  2011-02-01
#
#    paymentAmount  rentAmount  age       city            county    lat     lng  \
# 0         1321.0      1321.0   71  San Diego  San Diego County  32.60 -117.00
# 1         2289.0      2289.0  122  San Diego  San Diego County  32.82 -117.15
# 2         1439.0      1439.0  122  San Diego  San Diego County    NaN     NaN
# 3         1744.0      1744.0   45  San Diego  San Diego County    NaN     NaN
# 4         1471.0      1471.0   53  San Diego  San Diego County    NaN     NaN
#
#    housingUnits  occupiedHousingUnits  medianIncome  population state
# 0       21206.0               20202.0       57618.0     79708.0    CA
# 1       17268.0               16498.0       57350.0     45096.0    CA
# 2           NaN                   NaN           NaN         NaN    CA
# 3           NaN                   NaN           NaN         NaN    CA
# 4           NaN                   NaN           NaN         NaN    CA

# %%
#Info of the new added columns dataframe
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59813 entries, 0 to 59812
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   name                  59813 non-null  object
#  1   dob                   59813 non-null  object
#  2   houseID               59813 non-null  int64
#  3   houseZip              59813 non-null  int64
#  4   paymentDate           59813 non-null  object
#  5   paymentAmount         59813 non-null  float64
#  6   rentAmount            59813 non-null  float64
#  7   age                   59813 non-null  int64
#  8   city                  59813 non-null  object
#  9   county                59813 non-null  object
#  10  lat                   28178 non-null  float64
#  11  lng                   28178 non-null  float64
#  12  housingUnits          28178 non-null  float64
#  13  occupiedHousingUnits  28178 non-null  float64
#  14  medianIncome          23903 non-null  float64
#  15  population            28178 non-null  float64
#  16  state                 59813 non-null  object
# dtypes: float64(8), int64(3), object(6)
# memory usage: 7.8+ MB

# %%
#looking for nan value
new_df.isna().sum()
# Out:
# name                        0
# dob                         0
# houseID                     0
# houseZip                    0
# paymentDate                 0
# paymentAmount               0
# rentAmount                  0
# age                         0
# city                        0
# county                      0
# lat                     31635
# lng                     31635
# housingUnits            31635
# occupiedHousingUnits    31635
# medianIncome            35910
# population              31635
# state                       0
# dtype: int64

# %% [markdown]
# ### Recetly added columns from zipcode has missing information about lattitude, lngitude and other information which need to take care.

# %% [markdown]
# ## Converting PaymentDate to Binary
# ### Defining a function to convert to 1 0r 0, if payment date is before or after 10th of month.

# %%
new_df['paymentDate']=pd.to_datetime(new_df['paymentDate']).dt.date

# %%
# Defining a function to convert to 1 0r 0 if payment date is before or after 10 of month
def payment(x):
    if x.day>10:
        return 0
    else:
        return 1

# %%
# Applying the function
new_df['paymentDate']=new_df['paymentDate'].apply(payment)

# %%
# paymentDate columns
new_df['paymentDate'].value_counts()
# Out:
# 1    55580
# 0     4233
# Name: paymentDate, dtype: int64

# %% [markdown]
# ## Adding New Target Columns

# %% [markdown]
# ### Target column with high or low risk based on the overpayment and missing payment.

# %%
#Defining a function to convert to low risk and high risk
def low_high_risk(x,y):
    if (x==0.0 or x>y):
        return "high risk"
    else:
        return "low risk"

# %%
# Adding the target column status with low and high risk
new_df['status']=new_df.apply(lambda x: low_high_risk(x['paymentAmount'], x['rentAmount']), axis=1)

# %%
new_df.head()
# Out:
#                 name         dob  houseID  houseZip  paymentDate  \
# 0     Karima Germany  1951-05-23     1192     92154            1
# 1    Agustina Spargo  1900-01-01       21     92111            1
# 2  Lucilla Broderick  1900-01-01     1474     92159            1
# 3        Russ Mchale  1977-04-20     2015     92137            1
# 4   Carmelita Ritzer  1969-03-09      311     92136            1
#
#    paymentAmount  rentAmount  age       city            county    lat     lng  \
# 0         1321.0      1321.0   71  San Diego  San Diego County  32.60 -117.00
# 1         2289.0      2289.0  122  San Diego  San Diego County  32.82 -117.15
# 2         1439.0      1439.0  122  San Diego  San Diego County    NaN     NaN
# 3         1744.0      1744.0   45  San Diego  San Diego County    NaN     NaN
# 4         1471.0      1471.0   53  San Diego  San Diego County    NaN     NaN
#
#    housingUnits  occupiedHousingUnits  medianIncome  population state  \
# 0       21206.0               20202.0       57618.0     79708.0    CA
# 1       17268.0               16498.0       57350.0     45096.0    CA
# 2           NaN                   NaN           NaN         NaN    CA
# 3           NaN                   NaN           NaN         NaN    CA
# 4           NaN                   NaN           NaN         NaN    CA
#
#      status
# 0  low risk
# 1  low risk
# 2  low risk
# 3  low risk
# 4  low risk

# %%
# paymentDate columns
new_df['status'].value_counts()
# Out:
# low risk     52640
# high risk     7173
# Name: status, dtype: int64

# %% [markdown]
# ## Making Two Different Data Sets for Model Building:
# #### 1. Droping Columns with Missing Value
# #### 2. Dropping Rows with Missing any Value( Half of the data will be reduced using this method)

# %%
#Droping columns and rows with missing value
ml_df_col=new_df.drop(columns=['lat','lng', 'housingUnits',
                                  'occupiedHousingUnits','medianIncome', 'population'], axis=1)
ml_df_row=new_df.dropna(how="any")

# %%
# Data sets to store for MongoDB for website building
ml_df_row.to_csv('Resources/Cleaned_data/mongodb.csv', index=False)

# %% [markdown]
# # Under Sampling and Over Sampling for Model Building
# ### Since the data has very small number of low risk data, I used over sampling and under sampling to take care of it.

# %%
#Only considering low risk and high risk rows for column nan droped dataframe
low_risk_rows_col = ml_df_col[ml_df_col['status'] == 'low risk']
high_risk_rows_col = ml_df_col[ml_df_col['status'] == 'high risk']
low_risk_rows_col
# Out:
#                     name         dob  houseID  houseZip  paymentDate  \
# 0         Karima Germany  1951-05-23     1192     92154            1
# 1        Agustina Spargo  1900-01-01       21     92111            1
# 2      Lucilla Broderick  1900-01-01     1474     92159            1
# 3            Russ Mchale  1977-04-20     2015     92137            1
# 4       Carmelita Ritzer  1969-03-09      311     92136            1
# ...                  ...         ...      ...       ...          ...
# 59807    Marylouise Mott  1994-03-21     1633     92159            1
# 59808  Jennell Buchholtz  1983-05-21     1095     92196            1
# 59809     Berneice Power  1984-08-24      196     92123            1
# 59810       Micki Belvin  1900-01-01     1692     92166            1
# 59812    Astrid Laurence  1988-05-15      159     92120            1
#
#        paymentAmount  rentAmount  age       city            county state  \
# 0             1321.0      1321.0   71  San Diego  San Diego County    CA
# 1             2289.0      2289.0  122  San Diego  San Diego County    CA
# 2             1439.0      1439.0  122  San Diego  San Diego County    CA
# 3             1744.0      1744.0   45  San Diego  San Diego County    CA
# 4             1471.0      1471.0   53  San Diego  San Diego County    CA
# ...              ...         ...  ...        ...               ...   ...
# 59807         1342.0      1342.0   28  San Diego  San Diego County    CA
# 59808         1744.0      1744.0   39  San Diego  San Diego County    CA
# 59809         1756.0      1756.0   38  San Diego  San Diego County    CA
# 59810         1896.0      1896.0  122  San Diego  San Diego County    CA
# 59812         1134.0      1134.0   34  San Diego  San Diego County    CA
#
#          status
# 0      low risk
# 1      low risk
# 2      low risk
# 3      low risk
# 4      low risk
# ...         ...
# 59807  low risk
# 59808  low risk
# 59809  low risk
# 59810  low risk
# 59812  low risk
#
# [52640 rows x 12 columns]

# %%
#Only considering low risk and high risk rows for rows nan droped dataframe
low_risk_rows = ml_df_row[ml_df_row['status'] == 'low risk']
high_risk_rows = ml_df_row[ml_df_row['status'] == 'high risk']
low_risk_rows
# Out:
#                    name         dob  houseID  houseZip  paymentDate  \
# 0        Karima Germany  1951-05-23     1192     92154            1
# 1       Agustina Spargo  1900-01-01       21     92111            1
# 5       Clifton Ellwood  1993-11-02      430     92103            1
# 11          Taneka Noto  1992-05-09     2216     92110            1
# 14          Curtis Sher  1996-10-14      463     92130            1
# ...                 ...         ...      ...       ...          ...
# 59803     Anisa Gammill  1981-12-15      104     92116            1
# 59805   Freddie Bridger  1965-03-06      804     92145            1
# 59806  Millard Woodford  1900-01-01     1704     92129            1
# 59809    Berneice Power  1984-08-24      196     92123            1
# 59812   Astrid Laurence  1988-05-15      159     92120            1
#
#        paymentAmount  rentAmount  age       city            county    lat  \
# 0             1321.0      1321.0   71  San Diego  San Diego County  32.60
# 1             2289.0      2289.0  122  San Diego  San Diego County  32.82
# 5             1233.0      1233.0   29  San Diego  San Diego County  32.75
# 11             988.0       988.0   30  San Diego  San Diego County  32.77
# 14            1169.0      1169.0   26  San Diego  San Diego County  32.95
# ...              ...         ...  ...        ...               ...    ...
# 59803         1524.0      1524.0   41  San Diego  San Diego County  32.76
# 59805         1142.0      1142.0   57  San Diego  San Diego County  32.87
# 59806         -159.9      1066.0  122  San Diego  San Diego County  32.96
# 59809         1756.0      1756.0   38  San Diego  San Diego County  32.81
# 59812         1134.0      1134.0   34  San Diego  San Diego County  32.80
#
#           lng  housingUnits  occupiedHousingUnits  medianIncome  population  \
# 0     -117.00       21206.0               20202.0       57618.0     79708.0
# 1     -117.15       17268.0               16498.0       57350.0     45096.0
# 5     -117.17       19080.0               17827.0       62092.0     31066.0
# 11    -117.21       11426.0               10630.0       59719.0     25341.0
# 14    -117.20       18272.0               17528.0      127968.0     48940.0
# ...       ...           ...                   ...           ...         ...
# 59803 -117.13       17122.0               16138.0       53448.0     31680.0
# 59805 -117.14         407.0                 390.0      226875.0      1449.0
# 59806 -117.13       17439.0               17009.0      107870.0     51536.0
# 59809 -117.14       10760.0               10039.0       71412.0     26823.0
# 59812 -117.07       11411.0               10971.0       81000.0     26317.0
#
#       state    status
# 0        CA  low risk
# 1        CA  low risk
# 5        CA  low risk
# 11       CA  low risk
# 14       CA  low risk
# ...     ...       ...
# 59803    CA  low risk
# 59805    CA  low risk
# 59806    CA  low risk
# 59809    CA  low risk
# 59812    CA  low risk
#
# [20963 rows x 18 columns]

# %% [markdown]
# ## Under Sampling Technique

# %%
#Under sampling for rows nan droped dataframe
ml_df_under_row = pd.concat([low_risk_rows.sample(n=len(high_risk_rows), random_state=42), high_risk_rows])
ml_df_under_row = ml_df_under_row.reset_index(drop=True)
ml_df_under_row
# Out:
#                      name         dob  houseID  houseZip  paymentDate  \
# 0          Denny Paschall  1900-01-01      561     92130            1
# 1            Vita Lizaola  1976-10-21     2391     92105            1
# 2         Lanette Preston  1900-01-01     1318     92102            1
# 3     Janna Lautenschlage  1900-01-01     1048     92108            1
# 4       Rebekah Weatherly  1900-01-01     1927     92139            1
# ...                   ...         ...      ...       ...          ...
# 5875      Aurora Mccarley  1970-09-02      168     92154            0
# 5876         Paris Teston  1900-01-01     1861     92124            0
# 5877     Jazmine Rudisill  1972-09-21     1074     92105            0
# 5878        Jayme Hidalgo  1991-10-11     1064     92128            1
# 5879      Marita Iannuzzi  1900-01-01     1600     92124            0
#
#       paymentAmount  rentAmount  age       city            county    lat  \
# 0            1077.0      1077.0  122  San Diego  San Diego County  32.95
# 1            1125.0      1125.0   46  San Diego  San Diego County  32.74
# 2            1176.0      1176.0  122  San Diego  San Diego County  32.72
# 3            1489.0      1489.0  122  San Diego  San Diego County  32.77
# 4            1406.0      1406.0  122  San Diego  San Diego County  32.68
# ...             ...         ...  ...        ...               ...    ...
# 5875         1684.0      1531.0   52  San Diego  San Diego County  32.60
# 5876         2222.0      1778.0  122  San Diego  San Diego County  32.82
# 5877         2091.0      1901.0   50  San Diego  San Diego County  32.74
# 5878         2058.0      1871.0   31  San Diego  San Diego County  33.00
# 5879         1969.0      1713.0  122  San Diego  San Diego County  32.82
#
#          lng  housingUnits  occupiedHousingUnits  medianIncome  population  \
# 0    -117.20       18272.0               17528.0      127968.0     48940.0
# 1    -117.09       21744.0               20540.0       37534.0     69813.0
# 2    -117.12       14987.0               13981.0       40557.0     43267.0
# 3    -117.15       11601.0               10463.0       63098.0     18858.0
# 4    -117.05       10629.0               10216.0       58079.0     35125.0
# ...      ...           ...                   ...           ...         ...
# 5875 -117.00       21206.0               20202.0       57618.0     79708.0
# 5876 -117.07       11445.0               11038.0       80463.0     30443.0
# 5877 -117.09       21744.0               20540.0       37534.0     69813.0
# 5878 -117.07       21265.0               20263.0       92531.0     47490.0
# 5879 -117.07       11445.0               11038.0       80463.0     30443.0
#
#      state     status
# 0       CA   low risk
# 1       CA   low risk
# 2       CA   low risk
# 3       CA   low risk
# 4       CA   low risk
# ...    ...        ...
# 5875    CA  high risk
# 5876    CA  high risk
# 5877    CA  high risk
# 5878    CA  high risk
# 5879    CA  high risk
#
# [5880 rows x 18 columns]

# %%
#Under sampling for columns nan droped dataframe
ml_df_under_col = pd.concat([low_risk_rows_col.sample(n=len(high_risk_rows_col), random_state=42), high_risk_rows_col])
ml_df_under_col = ml_df_under_col.reset_index(drop=True)
ml_df_under_col
# Out:
#                       name         dob  houseID  houseZip  paymentDate  \
# 0           Isaiah Clayton  1900-01-01      985     92166            1
# 1          Harland Liggins  1983-11-28      910     92194            1
# 2           Almeda Sanders  1900-01-01       63     92113            1
# 3          Tiffany Demaris  2011-02-12     2275     92194            1
# 4            Leo Moorhouse  1900-01-01     1392     92147            1
# ...                    ...         ...      ...       ...          ...
# 14341      Marita Iannuzzi  1900-01-01     1600     92124            0
# 14342     Tomika Sylvestre  1968-09-20     2290     92133            0
# 14343       Delfina Snider  1900-01-01      538     92195            1
# 14344  Rudolph Fredrickson  1979-12-18     2007     92177            1
# 14345       Emilee Samford  1900-01-01      686     92191            0
#
#        paymentAmount  rentAmount  age       city            county state  \
# 0             1854.0      1854.0  122  San Diego  San Diego County    CA
# 1             1978.0      1978.0   39  San Diego  San Diego County    CA
# 2             1074.0      1074.0  122  San Diego  San Diego County    CA
# 3             1587.0      1587.0   11  San Diego  San Diego County    CA
# 4             1132.0      1132.0  122  San Diego  San Diego County    CA
# ...              ...         ...  ...        ...               ...   ...
# 14341         1969.0      1713.0  122  San Diego  San Diego County    CA
# 14342         1631.0      1483.0   54  San Diego  San Diego County    CA
# 14343         1710.0      1555.0  122  San Diego  San Diego County    CA
# 14344         2692.0      2154.0   43  San Diego  San Diego County    CA
# 14345         1668.0      1451.0  122  San Diego  San Diego County    CA
#
#           status
# 0       low risk
# 1       low risk
# 2       low risk
# 3       low risk
# 4       low risk
# ...          ...
# 14341  high risk
# 14342  high risk
# 14343  high risk
# 14344  high risk
# 14345  high risk
#
# [14346 rows x 12 columns]

# %%
# loking for the target columns after under sampling
ml_df_under_row['status'].value_counts()
# Out:
# low risk     2940
# high risk    2940
# Name: status, dtype: int64

# %%
#Saving the under sampling data for model
ml_df_under_row.to_csv('Resources/Cleaned_data/under_samp_row.csv', index=False)
ml_df_under_col.to_csv('Resources/Cleaned_data/under_samp_col.csv', index=False)

# %% [markdown]
# ## Over Sampling Technique

# %%
#Over sampling for rows nan droped dataframe
ml_df_over_row=pd.concat([low_risk_rows, high_risk_rows.sample(n=len(low_risk_rows), replace=True)])
ml_df_over_row= ml_df_over_row.reset_index(drop=True)
ml_df_over_row
# Out:
#                   name         dob  houseID  houseZip  paymentDate  \
# 0       Karima Germany  1951-05-23     1192     92154            1
# 1      Agustina Spargo  1900-01-01       21     92111            1
# 2      Clifton Ellwood  1993-11-02      430     92103            1
# 3          Taneka Noto  1992-05-09     2216     92110            1
# 4          Curtis Sher  1996-10-14      463     92130            1
# ...                ...         ...      ...       ...          ...
# 41921      Ivan Berrey  1989-03-13      992     92113            0
# 41922    Linsey Gallop  1900-01-01     1424     92103            0
# 41923  Lynnette Menzie  1900-01-01     1500     92102            0
# 41924    Lloyd Holbert  1900-01-01     1437     92115            0
# 41925    Sherice Fabre  1900-01-01     2117     92117            1
#
#        paymentAmount  rentAmount  age       city            county    lat  \
# 0             1321.0      1321.0   71  San Diego  San Diego County  32.60
# 1             2289.0      2289.0  122  San Diego  San Diego County  32.82
# 2             1233.0      1233.0   29  San Diego  San Diego County  32.75
# 3              988.0       988.0   30  San Diego  San Diego County  32.77
# 4             1169.0      1169.0   26  San Diego  San Diego County  32.95
# ...              ...         ...  ...        ...               ...    ...
# 41921         1474.0      1282.0   33  San Diego  San Diego County  32.69
# 41922         1545.0      1344.0  122  San Diego  San Diego County  32.75
# 41923         1652.0      1437.0  122  San Diego  San Diego County  32.72
# 41924         1991.0      1810.0  122  San Diego  San Diego County  32.76
# 41925         1556.0      1245.0  122  San Diego  San Diego County  32.81
#
#           lng  housingUnits  occupiedHousingUnits  medianIncome  population  \
# 0     -117.00       21206.0               20202.0       57618.0     79708.0
# 1     -117.15       17268.0               16498.0       57350.0     45096.0
# 2     -117.17       19080.0               17827.0       62092.0     31066.0
# 3     -117.21       11426.0               10630.0       59719.0     25341.0
# 4     -117.20       18272.0               17528.0      127968.0     48940.0
# ...       ...           ...                   ...           ...         ...
# 41921 -117.12       13196.0               12315.0       27675.0     56066.0
# 41922 -117.17       19080.0               17827.0       62092.0     31066.0
# 41923 -117.12       14987.0               13981.0       40557.0     43267.0
# 41924 -117.07       22754.0               21251.0       41866.0     58560.0
# 41925 -117.20       21466.0               20658.0       64026.0     51332.0
#
#       state     status
# 0        CA   low risk
# 1        CA   low risk
# 2        CA   low risk
# 3        CA   low risk
# 4        CA   low risk
# ...     ...        ...
# 41921    CA  high risk
# 41922    CA  high risk
# 41923    CA  high risk
# 41924    CA  high risk
# 41925    CA  high risk
#
# [41926 rows x 18 columns]

# %%
#Over sampling for columns nan droped dataframe
ml_df_over_col=pd.concat([low_risk_rows_col, high_risk_rows_col.sample(n=len(low_risk_rows_col), replace=True)])
ml_df_over_col= ml_df_over_col.reset_index(drop=True)
ml_df_over_col
# Out:
#                      name         dob  houseID  houseZip  paymentDate  \
# 0          Karima Germany  1951-05-23     1192     92154            1
# 1         Agustina Spargo  1900-01-01       21     92111            1
# 2       Lucilla Broderick  1900-01-01     1474     92159            1
# 3             Russ Mchale  1977-04-20     2015     92137            1
# 4        Carmelita Ritzer  1969-03-09      311     92136            1
# ...                   ...         ...      ...       ...          ...
# 105275    Beckie Balbuena  1984-06-14      187     92135            0
# 105276      Randi Keppler  1900-01-01     1912     92163            0
# 105277         Alex Earle  2001-11-02       43     92149            0
# 105278     Blair Schroder  1973-08-01      216     92122            0
# 105279    Christi Schantz  1900-01-01      396     92120            0
#
#         paymentAmount  rentAmount  age       city            county state  \
# 0              1321.0      1321.0   71  San Diego  San Diego County    CA
# 1              2289.0      2289.0  122  San Diego  San Diego County    CA
# 2              1439.0      1439.0  122  San Diego  San Diego County    CA
# 3              1744.0      1744.0   45  San Diego  San Diego County    CA
# 4              1471.0      1471.0   53  San Diego  San Diego County    CA
# ...               ...         ...  ...        ...               ...   ...
# 105275         2165.0      1883.0   38  San Diego  San Diego County    CA
# 105276         1480.0      1346.0  122  San Diego  San Diego County    CA
# 105277         1713.0      1490.0   21  San Diego  San Diego County    CA
# 105278         1712.0      1557.0   49  San Diego  San Diego County    CA
# 105279         1766.0      1536.0  122  San Diego  San Diego County    CA
#
#            status
# 0        low risk
# 1        low risk
# 2        low risk
# 3        low risk
# 4        low risk
# ...           ...
# 105275  high risk
# 105276  high risk
# 105277  high risk
# 105278  high risk
# 105279  high risk
#
# [105280 rows x 12 columns]

# %%
# Loking for the target columns after over sampling technique
ml_df_over_col['status'].value_counts()
# Out:
# low risk     52640
# high risk    52640
# Name: status, dtype: int64

# %%
#Saving the over sampling data for model building
ml_df_over_row.to_csv('Resources/Cleaned_data/over_samp_row.csv', index=False)
ml_df_over_col.to_csv('Resources/Cleaned_data/over_samp_col.csv', index=False)
